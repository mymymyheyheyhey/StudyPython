# %%
from PIL import Image

# %%
img = Image.open('C:\\Sources\\StudyPython\\pic\\wa.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x265826B2440>

# %%
img = img.resize((100, 100))
img
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x265F2343F70>

# %%
import numpy as np
imgArray = np.array(img)
imgArray
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <module>
#       1 import numpy as np
# ----> 2 imgArray = np.array(img)
#       3 imgArray
#
# NameError: name 'img' is not defined

# %%
import matplotlib.pyplot as plt
plt.imshow(imgArray * [0, 1, 0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.imshow(imgArray * [0, 1, 0])
#
# NameError: name 'imgArray' is not defined

# %%
plt.imshow(imgArray * [1, 0, 0])

# %%
plt.imshow(imgArray * [0, 0, 1])
